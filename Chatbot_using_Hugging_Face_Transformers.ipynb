# %% [markdown]
# ⭐**Chatbot Using Hugging Face Transformers(DialoGPT)**

# %% [markdown]
# **Objective** : Build a chatbot using a pre-trained transformer model (DialoGPT) that interacts with users and generates responses.
# It generates human-like responses based on user input using NLP techniques.

# %%
# Transformers Installation

# !pip install transformers torch

# %% [markdown]
# **Import Libraries** : We import required modules from transformers and torch.

# %%
# Import Libraries

from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %% [markdown]
# **Load Pre-tained Model** : We load pre-tained model DialoGPT from Hugging Face

# %%
# Load Model

tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-medium")
model = AutoModelForCausalLM.from_pretrained("microsoft/DialoGPT-medium")

# %% [markdown]
# **Chatbot Implementation** : This chatbot takes user input, processes it using the transformer model, and generates responses.

# %%
chat_history_ids = None

print("Chatbot: Hello! I am your AI assistant. Type 'exit' to stop.")

while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye! 👋")
        break

    # Encode user input
    new_input_ids = tokenizer.encode(user_input + tokenizer.eos_token, return_tensors='pt')

    # Combine with chat history
    if chat_history_ids is not None:
        bot_input_ids = torch.cat([chat_history_ids, new_input_ids], dim=-1)
    else:
        bot_input_ids = new_input_ids

    # Generate response
    chat_history_ids = model.generate(
        bot_input_ids,
        max_length=1000,
        pad_token_id=tokenizer.eos_token_id,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        repetition_penalty=1.2
    )

    # Decode response
    bot_output = tokenizer.decode(
        chat_history_ids[:, bot_input_ids.shape[-1]:][0],
        skip_special_tokens=True
    )

    print("Chatbot:", bot_output)

# %% [markdown]
# **Output** : Chatbot: Hello! I am your AI assistant. Type 'exit' to stop.
# You: hello
# Chatbot: You're welcome. Nice to meet you!
# You: what is AI?
# Chatbot: AI Artificial Intelligence
# You: Exit
# Chatbot: Goodbye! 👋

# %% [markdown]
# **Conclusion** :
#
# In this project, I built a chatbot using transformer model like DialoGPT. It can generate human-like responses using NLP techniques.
# I learned how chatbot models work and how to improve their responses. This project helped me understand the basics of conversational AI.
